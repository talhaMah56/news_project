# %%
# !pip install --upgrade pip
# !pip install uv
# !uv pip install -r requirements.txt
#if does not work, remove uv from command
# Out:
# Requirement already satisfied: pip in ./.venv/lib/python3.9/site-packages (25.1.1)
# Requirement already satisfied: uv in ./.venv/lib/python3.9/site-packages (0.7.5)
# Audited 16 packages in 32ms

# %%
# %run analysis.py --verbose
# Out:
# ==================================================
# === MIT_AI EDA ===
# ==================================================
#
# === DataFrame Basic Info ================
# Shape: (1018, 8)
#
# === First 5 Rows =======================
#    Unnamed: 0 Published Date                Author  \
# 0           0   July 7, 2023             Adam Zewe
# 1           1   July 6, 2023           Alex Ouyang
# 2           2  June 30, 2023  Jennifer Michalowski
# 3           3  June 30, 2023   Mary Beth Gallagher
# 4           4  June 30, 2023             Adam Zewe
#
#                                               Source  \
# 0                                    MIT News Office
# 1  Abdul Latif Jameel Clinic for Machine Learning...
# 2              McGovern Institute for Brain Research
# 3                              School of Engineering
# 4                                    MIT News Office
#
#                                       Article Header  \
# 0  Learning the language of molecules to predict ...
# 1  MIT scientists build a system that can generat...
# 2  When computer vision works more like a brain, ...
# 3  Educating national security leaders on artific...
# 4  Researchers teach an AI to write better chart ...
#
#                                         Sub_Headings  \
# 0  This AI system only needs a small amount of da...
# 1  BioAutoMATED, an open-source, automated machin...
# 2  Training artificial neural networks with data ...
# 3  Experts from MIT’s School of Engineering, Schw...
# 4  A new dataset can help scientists develop auto...
#
#                                         Article Body  \
# 0  ['Discovering new materials and drugs typicall...
# 1  ['Is it possible to build machine-learning mod...
# 2  ['From cameras to self-driving cars, many of t...
# 3  ['Understanding artificial intelligence and ho...
# 4  ['Chart captions that explain complex trends a...
#
#                                                  Url
# 0  https://news.mit.edu/2023/learning-language-mo...
# 1  https://news.mit.edu/2023/bioautomated-open-so...
# 2  https://news.mit.edu/2023/when-computer-vision...
# 3  https://news.mit.edu/2023/educating-national-s...
# 4  https://news.mit.edu/2023/researchers-chart-ca...
#
# === Data Types =========================
# Unnamed: 0         int64
# Published Date    object
# Author            object
# Source            object
# Article Header    object
# Sub_Headings      object
# Article Body      object
# Url               object
# dtype: object
#
# === Missing Values =====================
# Unnamed: 0          0
# Published Date      0
# Author            170
# Source            186
# Article Header      0
# Sub_Headings      148
# Article Body        0
# Url                 0
# dtype: int64
#
# === Title Analysis ===
#
# Average title length: 53.2 characters
# Average word count: 7.9 words
#
# Top 20 title keywords (excluding stop words):
# mit: 179
# intelligence: 129
# artificial: 118
# learning: 99
# new: 77
# machine: 68
# robot: 65
# robots: 62
# computing: 48
# data: 42
# future: 33
# human: 30
# robotic: 30
# models: 28
# using: 25
# health: 25
# research: 24
# computer: 24
# like: 24
# model: 24
# === Source Analysis ===
#
# Top 10 sources:
# sources
# MIT News Office...    340
# MIT CSAIL...          121
# MIT Quest for I...     47
# School of Engin...     43
# MIT Schwarzman ...     31
# MIT Media Lab...       14
# MIT News corres...     14
# MIT Open Learni...     13
# MIT-IBM Watson ...     12
# Department of M...     11
# Name: count, dtype: int64
# Top 10 sources:
# domain
# mit.edu    1018
# Name: count, dtype: int64
# === Temporal Analysis ===
#
# Monthly article counts:
# date
# 1994-03-01     1
# 1994-04-01     1
# 1994-05-01     1
# 1994-06-01     1
# 1994-09-01     2
#               ..
# 2023-03-01    14
# 2023-04-01     7
# 2023-05-01    21
# 2023-06-01    19
# 2023-07-01     2
# Length: 221, dtype: int64
# ==================================================
# === AI_Tech EDA ===
# ==================================================
#
# === DataFrame Basic Info ================
# Shape: (17092, 5)
#
# === First 5 Rows =======================
#    id  year                                              title  \
# 0   0  2016  "Human-Animal Chimeras Are Gestating on U.S. R...
# 1   1  2013     "Too Much Information | MIT Technology Review"
# 2   2  2017  "Hacking the Biological Clock | MIT Technology...
# 3   3  2018  "Six things to do with your data before you di...
# 4   4  2018   "Your genome, on demand | MIT Technology Review"
#
#                                                  url  \
# 0  "https://www.technologyreview.com/s/545106/hum...
# 1  "https://www.technologyreview.com/s/522661/too...
# 2  "https://www.technologyreview.com/magazines/ha...
# 3  "https://www.technologyreview.com/2018/10/23/2...
# 4  "https://www.technologyreview.com/2018/10/23/1...
#
#                                                 text
# 0  "Featured Topics Newsletters Events Podcasts F...
# 1  "Featured Topics Newsletters Events Podcasts F...
# 2  "Featured Topics Newsletters Events Podcasts F...
# 3  "Featured Topics Newsletters Events Podcasts F...
# 4  "Featured Topics Newsletters Events Podcasts F...
#
# === Data Types =========================
# id        int64
# year      int64
# title    object
# url      object
# text     object
# dtype: object
#
# === Missing Values =====================
# id       0
# year     0
# title    0
# url      0
# text     0
# dtype: int64
#
# === Title Analysis ===
#
# Average title length: 76.7 characters
# Average word count: 12.0 words
#
# Top 20 title keywords (excluding stop words):
# venturebeat: 11065
# wired: 2820
# technology: 1182
# review: 1175
# data: 1119
# google: 1110
# mit: 998
# new: 957
# verge: 810
# raises: 634
# million: 617
# tech: 571
# apple: 542
# microsoft: 522
# guardian: 521
# launches: 488
# facebook: 481
# cloud: 470
# amazon: 469
# learning: 465
# === Source Analysis ===
# Source analysis not available for AI_Tech dataset.
#
# Top 10 sources:
# domain
# venturebeat.com           11009
# wired.com                  2780
# technologyreview.com        958
# theverge.com                809
# theguardian.com             481
# theatlantic.com             294
# deeplearningindaba.com      152
# vox.com                     137
# openai.com                  133
# newyorker.com                75
# Name: count, dtype: int64
# === Temporal Analysis ===
#
# Monthly article counts:
# date
# 2000-02-01      2
# 2000-03-01      3
# 2000-04-01      4
# 2000-05-01      1
# 2000-06-01      4
#              ...
# 2023-08-01    301
# 2023-09-01    300
# 2023-10-01    317
# 2023-11-01    288
# 2023-12-01    324
# Length: 240, dtype: int64
# ==================================================
# === combined_dataset EDA ===
# ==================================================
#
# === DataFrame Basic Info ================
# Shape: (18110, 7)
#
# === First 5 Rows =======================
#          date                                              title  \
# 0  2023-07-31  Learning the language of molecules to predict ...
# 1  2023-07-31  MIT scientists build a system that can generat...
# 2  2023-06-30  When computer vision works more like a brain, ...
# 3  2023-06-30  Educating national security leaders on artific...
# 4  2023-06-30  Researchers teach an AI to write better chart ...
#
#    title_length  word_count  \
# 0            62           9
# 1            78          13
# 2            73          14
# 3            62           7
# 4            54           9
#
#                                                 text  \
# 0  ['Discovering new materials and drugs typicall...
# 1  ['Is it possible to build machine-learning mod...
# 2  ['From cameras to self-driving cars, many of t...
# 3  ['Understanding artificial intelligence and ho...
# 4  ['Chart captions that explain complex trends a...
#
#                                                  url  \
# 0  https://news.mit.edu/2023/learning-language-mo...
# 1  https://news.mit.edu/2023/bioautomated-open-so...
# 2  https://news.mit.edu/2023/when-computer-vision...
# 3  https://news.mit.edu/2023/educating-national-s...
# 4  https://news.mit.edu/2023/researchers-chart-ca...
#
#                                              sources
# 0                                    MIT News Office
# 1  Abdul Latif Jameel Clinic for Machine Learning...
# 2              McGovern Institute for Brain Research
# 3                              School of Engineering
# 4                                    MIT News Office
#
# === Data Types =========================
# date            object
# title           object
# title_length     int64
# word_count       int64
# text            object
# url             object
# sources         object
# dtype: object
#
# === Missing Values =====================
# date                0
# title               0
# title_length        0
# word_count          0
# text                0
# url                 0
# sources         17278
# dtype: int64
#
# === Title Analysis ===
#
# Average title length: 75.3 characters
# Average word count: 11.8 words
#
# Top 20 title keywords (excluding stop words):
# venturebeat: 11065
# wired: 2820
# technology: 1203
# mit: 1177
# review: 1176
# data: 1161
# google: 1110
# new: 1034
# verge: 810
# raises: 634
# million: 622
# tech: 577
# learning: 564
# apple: 542
# intelligence: 530
# microsoft: 522
# guardian: 521
# launches: 498
# facebook: 481
# amazon: 471
# === Source Analysis ===
#
# Top 10 sources:
# sources
# MIT News Office...    340
# MIT CSAIL...          121
# MIT Quest for I...     47
# School of Engin...     43
# MIT Schwarzman ...     31
# MIT Media Lab...       14
# MIT News corres...     14
# MIT Open Learni...     13
# MIT-IBM Watson ...     12
# Department of M...     11
# Name: count, dtype: int64
# Top 10 sources:
# domain
# venturebeat.com           11009
# wired.com                  2780
# mit.edu                    1018
# technologyreview.com        958
# theverge.com                809
# theguardian.com             481
# theatlantic.com             294
# deeplearningindaba.com      152
# vox.com                     137
# openai.com                  133
# Name: count, dtype: int64
# === Temporal Analysis ===
#
# Monthly article counts:
# date
# 1994-03-31      1
# 1994-04-30      1
# 1994-05-31      1
# 1994-06-30      1
# 1994-09-30      2
#              ...
# 2023-08-31    301
# 2023-09-30    300
# 2023-10-31    317
# 2023-11-30    288
# 2023-12-31    324
# Length: 294, dtype: int64
# Batches: 100%|██████████| 566/566 [00:13<00:00, 43.26it/s]
# 2025-05-27 20:10:49,739 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-05-27 20:11:01,517 - BERTopic - Dimensionality - Completed ✓
# 2025-05-27 20:11:01,518 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-05-27 20:11:01,951 - BERTopic - Cluster - Completed ✓
# 2025-05-27 20:11:01,956 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-05-27 20:11:08,679 - BERTopic - Representation - Completed ✓
#      Topic  Count                                         Name  \
# 0       -1   5922       -1_venturebeat_ai_microsoft_enterprise
# 1        0    195       0_venturebeat_analytics_data_databases
# 2        1    184    1_venturebeat_ai_entrepreneurs_enterprise
# 3        2    180           2_metaverse_viverse_meta_metahuman
# 4        3    179           3_mit_tech_technologies_technology
# ..     ...    ...                                          ...
# 351    350      5  350_docker_venturebeat_container_enterprise
# 352    351      5              351_venturebeat_ai_intel_builds
# 353    352      5    352_venturebeat_cloud_jumpcloud_cloudzero
# 354    353      5   353_pokémon_venturebeat_nintendo_minecraft
# 355    354      5             354_ai_disinformation_news_prose
#
#                                         Representation  Representative_Docs
# 0    [venturebeat, ai, microsoft, enterprise, machi...                  NaN
# 1    [venturebeat, analytics, data, databases, data...                  NaN
# 2    [venturebeat, ai, entrepreneurs, enterprise, e...                  NaN
# 3    [metaverse, viverse, meta, metahuman, virtual,...                  NaN
# 4    [mit, tech, technologies, technology, review, ...                  NaN
# ..                                                 ...                  ...
# 351  [docker, venturebeat, container, enterprise, c...                  NaN
# 352  [venturebeat, ai, intel, builds, appcoder, cod...                  NaN
# 353  [venturebeat, cloud, jumpcloud, cloudzero, cos...                  NaN
# 354  [pokémon, venturebeat, nintendo, minecraft, pe...                  NaN
# 355  [ai, disinformation, news, prose, technology, ...                  NaN
#
# [356 rows x 5 columns]
# 2025-05-27 20:11:09,876 - BERTopic - WARNING: There are more than 100 unique timestamps (i.e., 294) which significantly slows down the application. Consider setting `nr_bins` to a value lower than 100 to speed up calculation.
# 294it [00:07, 37.48it/s]
# 20:11:17 - cmdstanpy - INFO - Chain [1] start processing
# 20:11:18 - cmdstanpy - INFO - Chain [1] done processing
# 20:11:18 - cmdstanpy - INFO - Chain [1] start processing
# Topics over time values saved to: /Users/talha56/Developer/edu/PYS612/news_project/logs/combined_dataset_topics_over_time_log.txt
#
# === Prophet Model Results (Linear) ===
# Image suffix: articles
#
# Training Metrics:
#   R² Score: 0.9607
#   L2 (MSE): 56.8413
#   Chi²:     3869.5136
#
# Testing Metrics:
#   R² Score: 0.2963
#   L2 (MSE): 2445.3421
#   Chi²:     699.8244
# ==================================================
# 20:11:18 - cmdstanpy - INFO - Chain [1] done processing
# === Prophet Model Results (Exponential (Logistic)) ===
# Image suffix: articles
#
# Training Metrics:
#   R² Score: 0.9468
#   L2 (MSE): 76.9978
#   Chi²:     4284.3090
#
# Testing Metrics:
#   R² Score: -2.0836
#   L2 (MSE): 10716.0699
#   Chi²:     1820.2523
# ==================================================
#
# ADF Test Results:
# ADF Statistic: 4.5460
# p-value: 1.0000
# Critical Values:
#    1%: -3.4538
#    5%: -2.8718
#    10%: -2.5723
# Result: The series is not stationary.
# ARIMA Model Summary:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              Frequency   No. Observations:                  299
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -1002.058
# Date:                Tue, 27 May 2025   AIC                           2014.115
# Time:                        20:11:18   BIC                           2032.601
# Sample:                    03-31-1994   HQIC                          2021.515
#                          - 01-31-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4786      0.116     -4.119      0.000      -0.706      -0.251
# ar.L2         -0.5184      0.038    -13.706      0.000      -0.593      -0.444
# ma.L1         -0.0508      0.112     -0.455      0.649      -0.270       0.168
# ma.L2          0.2331      0.085      2.748      0.006       0.067       0.399
# sigma2        48.6942      1.575     30.915      0.000      45.607      51.781
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):              4734.78
# Prob(Q):                              0.64   Prob(JB):                         0.00
# Heteroskedasticity (H):              79.46   Skew:                             2.82
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# === ARIMA Model Results (Linear) ===
# Order: (2, 1, 2)
# Image suffix: articles_lin
#
# Training Metrics:
#   R² Score: 0.9603
#   L2 (MSE): 48.5347
#   Chi²:     10000000613.6414
#
# Testing Metrics:
#   R² Score: -0.6025
#   L2 (MSE): 5568.8203
#   Chi²:     2000.4569
# ==================================================
# ADF Test Results:
# ADF Statistic: 4.5460
# p-value: 1.0000
# Critical Values:
#    1%: -3.4538
#    5%: -2.8718
#    10%: -2.5723
# Result: The series is not stationary.
# ARIMA Model Summary:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              Frequency   No. Observations:                  299
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -203.877
# Date:                Tue, 27 May 2025   AIC                            417.755
# Time:                        20:11:19   BIC                            436.240
# Sample:                    03-31-1994   HQIC                           425.154
#                          - 01-31-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2398      0.483     -0.496      0.620      -1.187       0.708
# ar.L2         -0.0524      0.157     -0.334      0.738      -0.360       0.255
# ma.L1         -0.3164      0.486     -0.651      0.515      -1.268       0.636
# ma.L2         -0.2551      0.399     -0.639      0.523      -1.038       0.527
# sigma2         0.2296      0.016     14.073      0.000       0.198       0.262
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 7.97
# Prob(Q):                              0.84   Prob(JB):                         0.02
# Heteroskedasticity (H):               0.52   Skew:                             0.11
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# === ARIMA Model Results (Exponential (Log-transformed)) ===
# Order: (2, 1, 2)
# Image suffix: articles_exp
#
# Training Metrics:
#   R² Score: 0.9517
#   L2 (MSE): 58.9939
#   Chi²:     683.4714
#
# Testing Metrics:
#   R² Score: -1.3084
#   L2 (MSE): 8022.1324
#   Chi²:     3323.5912
# ==================================================
# 20:11:19 - cmdstanpy - INFO - Chain [1] start processing
# 20:11:19 - cmdstanpy - INFO - Chain [1] done processing
# === Prophet Model Results (Linear) ===
# Image suffix: topics
#
# Training Metrics:
#   R² Score: 0.9633
#   L2 (MSE): 11.1419
#   Chi²:     601.8356
#
# Testing Metrics:
#   R² Score: 0.4927
#   L2 (MSE): 146.6043
#   Chi²:     104.5937
# ==================================================
# 20:11:19 - cmdstanpy - INFO - Chain [1] start processing
# 20:11:19 - cmdstanpy - INFO - Chain [1] done processing
# === Prophet Model Results (Exponential (Logistic)) ===
# Image suffix: topics
#
# Training Metrics:
#   R² Score: 0.9481
#   L2 (MSE): 15.7364
#   Chi²:     1581.1998
#
# Testing Metrics:
#   R² Score: -14.2353
#   L2 (MSE): 4402.8613
#   Chi²:     1473.1336
# ==================================================
#
# ADF Test Results:
# ADF Statistic: 4.5451
# p-value: 1.0000
# Critical Values:
#    1%: -3.4534
#    5%: -2.8717
#    10%: -2.5722
# Result: The series is not stationary.
# ARIMA Model Summary:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              Frequency   No. Observations:                  299
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -788.184
# Date:                Tue, 27 May 2025   AIC                           1586.367
# Time:                        20:11:20   BIC                           1604.853
# Sample:                    03-31-1994   HQIC                          1593.767
#                          - 01-31-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9673      0.090    -10.754      0.000      -1.144      -0.791
# ar.L2         -0.2481      0.070     -3.548      0.000      -0.385      -0.111
# ma.L1          0.4060      0.099      4.091      0.000       0.211       0.600
# ma.L2         -0.3241      0.074     -4.386      0.000      -0.469      -0.179
# sigma2        11.5917      0.311     37.221      0.000      10.981      12.202
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):              9036.39
# Prob(Q):                              0.77   Prob(JB):                         0.00
# Heteroskedasticity (H):              58.40   Skew:                             3.70
# Prob(H) (two-sided):                  0.00   Kurtosis:                        28.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# === ARIMA Model Results (Linear) ===
# Order: (2, 1, 2)
# Image suffix: topics_lin
#
# Training Metrics:
#   R² Score: 0.9551
#   L2 (MSE): 11.5562
#   Chi²:     10000000274.2305
#
# Testing Metrics:
#   R² Score: -0.7239
#   L2 (MSE): 498.1939
#   Chi²:     412.3328
# ==================================================
# ADF Test Results:
# ADF Statistic: 4.5451
# p-value: 1.0000
# Critical Values:
#    1%: -3.4534
#    5%: -2.8717
#    10%: -2.5722
# Result: The series is not stationary.
# ARIMA Model Summary:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              Frequency   No. Observations:                  299
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -148.023
# Date:                Tue, 27 May 2025   AIC                            306.045
# Time:                        20:11:20   BIC                            324.531
# Sample:                    03-31-1994   HQIC                           313.445
#                          - 01-31-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0595      1.822     -0.033      0.974      -3.630       3.511
# ar.L2          0.0234      0.448      0.052      0.958      -0.854       0.901
# ma.L1         -0.4789      1.820     -0.263      0.792      -4.045       3.088
# ma.L2         -0.2002      1.417     -0.141      0.888      -2.978       2.577
# sigma2         0.1578      0.010     16.086      0.000       0.139       0.177
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                41.36
# Prob(Q):                              0.80   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.98   Skew:                             0.24
# Prob(H) (two-sided):                  0.92   Kurtosis:                         4.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# === ARIMA Model Results (Exponential (Log-transformed)) ===
# Order: (2, 1, 2)
# Image suffix: topics_exp
#
# Training Metrics:
#   R² Score: 0.9477
#   L2 (MSE): 13.4708
#   Chi²:     328.4748
#
# Testing Metrics:
#   R² Score: -1.6030
#   L2 (MSE): 752.2446
#   Chi²:     692.0225
# ==================================================
